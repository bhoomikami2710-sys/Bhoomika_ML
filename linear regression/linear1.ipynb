# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('jee.csv')

# %%
df.head()
# Out:
#    12th_Marks  JEE_Percentile
# 0          96           88.04
# 1         100           58.54
# 2          62           91.12
# 3          74           66.92
# 4          62           60.68

# %%
plt.scatter(df['12th_Marks'],df['JEE_Percentile'])
plt.xlabel('Marks')
plt.ylabel('Percentile)')
# Out:
# Text(0, 0.5, 'Percentile)')

# %%
X = df.iloc[:,1:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     JEE_Percentile
# 0            88.04
# 1            58.54
# 2            91.12
# 3            66.92
# 4            60.68
# ..             ...
# 95           59.13
# 96           77.91
# 97           86.03
# 98           52.39
# 99           93.98
#
# [100 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)

# %%
X_train
# Out:
#     JEE_Percentile
# 35           52.12
# 11           87.87
# 84           90.64
# 44           96.38
# 73           57.07
# ..             ...
# 43           86.41
# 22           58.06
# 72           82.79
# 15           85.84
# 40           57.31
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     JEE_Percentile
# 83           92.67
# 30           63.70
# 56           83.78
# 24           90.96
# 16           93.54
# 23           66.29
# 2            91.12
# 27           77.55
# 28           75.41
# 13           80.48
# 99           93.98
# 92           93.65
# 76           82.70
# 14           95.89
# 0            88.04
# 21           85.39
# 3            66.92
# 29           57.75
# 61           82.65
# 79           98.61

# %%
y_test
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92.67])

# %%
plt.scatter(df['12th_Marks'], df['JEE_Percentile'])
plt.plot(X_train, lr.predict(X_train), color='green')
plt.xlabel('12th Marks')
plt.ylabel('JEE Percentile')
# Out:
# Text(0, 0.5, 'JEE Percentile')

# %%
m = lr.coef_
m
# Out:
# array([1.])

# %%
b = lr.intercept_
b
# Out:
# np.float64(0.0)

# %%
m * 80.48 + b
# Out:
# array([80.48])
