# %%
import pandas as pd

# %%
df = pd.read_csv('flight.csv')

# %%
df.head()
# Out:
#    flight_id   airline source_city destination_city departure_time     stops  \
# 0          1    Indigo       Delhi           Mumbai        Morning  non-stop
# 1          2  AirIndia      Mumbai        Bangalore        Evening    1-stop
# 2          3  SpiceJet       Delhi          Chennai      Afternoon    1-stop
# 3          4   Vistara     Kolkata            Delhi        Morning  non-stop
# 4          5    Indigo   Bangalore           Mumbai          Night   2+-stop
#
#    duration_hours  days_left  price
# 0             2.5         15   5200
# 1             5.0         10   6400
# 2             4.5          7   5900
# 3             2.0         20   4500
# 4             7.5          5   7200

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/bhoomikami2710-sys/Bhoomika_ML/refs/heads/main/csv/spotify.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#         Unnamed: 0.1  Unnamed: 0                track_id  \
# 0                  0           0  5SuOikwiRyPMVoIQDJUgSV
# 1                  1           1  4qPNDBW1i3p13qLCt0Ki3A
# 2                  2           2  1iJBSr7s7jYXzM8EGcbK5b
# 3                  3           3  6lfxq3CG4xtTiEg7opyCyx
# 4                  4           4  5vjLSffimiIP26QG5WcN2K
# ...              ...         ...                     ...
# 113995        113995      113995  2C3TZjDRiAzdyViavDJ217
# 113996        113996      113996  1hIz5L4IB9hN3WRYPOCGPw
# 113997        113997      113997  6x8ZfSoqDjuNa5SVP5QjvX
# 113998        113998      113998  2e6sXL2bYv4bSz6VTdnfLs
# 113999        113999      113999  2hETkH7cOfqmz3LqZDHZf5
#
#                        artists  \
# 0                  Gen Hoshino
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113995           Rainy Lullaby
# ...

# %%
pd.read_csv('student.tsv',sep='\t')
# Out:
#     StudentID  CGPA  Internships  Projects  Package_LPA
# 0         101   8.1            2         3          6.5
# 1         102   7.5            1         2          5.2
# 2         103   9.0            3         4          9.1
# 3         104   6.8            0         2          4.0
# 4         105   8.7            2         5          8.3
# 5         106   7.9            1         3          6.0
# 6         107   9.3            4         6         10.5
# 7         108   6.5            0         1          3.8
# 8         109   8.4            2         4          7.2
# 9         110   7.2            1         2          5.0
# 10        111   8.9            3         5          8.9
# 11        112   6.9            1         2          4.5
# 12        113   9.5            4         6         11.2
# 13        114   7.8            2         3          6.3
# 14        115   8.2            2         4          7.5
# 15        116   7.4            1         2          5.6
# ...

# %%
pd.read_csv('student.tsv', sep='\t', index_col='StudentID')
# Out:
#            CGPA  Internships  Projects  Package_LPA
# StudentID
# 101         8.1            2         3          6.5
# 102         7.5            1         2          5.2
# 103         9.0            3         4          9.1
# 104         6.8            0         2          4.0
# 105         8.7            2         5          8.3
# 106         7.9            1         3          6.0
# 107         9.3            4         6         10.5
# 108         6.5            0         1          3.8
# 109         8.4            2         4          7.2
# 110         7.2            1         2          5.0
# 111         8.9            3         5          8.9
# 112         6.9            1         2          4.5
# 113         9.5            4         6         11.2
# 114         7.8            2         3          6.3
# 115         8.2            2         4          7.5
# 116         7.4            1         2          5.6
# 117         8.6            3         5          8.1
# ...

# %%
df = pd.read_csv('flight.csv',header=4)
df
# Out:
#      4   Vistara    Kolkata      Delhi    Morning  non-stop  2.0  20  4500
# 0    5    Indigo  Bangalore     Mumbai      Night   2+-stop  7.5   5  7200
# 1    6   AirAsia      Delhi    Kolkata  Afternoon  non-stop  2.2  18  4100
# 2    7     GoAir     Mumbai    Chennai    Evening    1-stop  4.0  12  5600
# 3    8   Vistara    Chennai      Delhi    Morning  non-stop  2.8  25  4800
# 4    9  SpiceJet  Bangalore    Kolkata      Night    1-stop  5.5   9  6100
# 5   10    Indigo      Delhi  Bangalore  Afternoon  non-stop  2.6  30  5300
# 6   11  AirIndia    Kolkata     Mumbai    Morning    1-stop  4.8   6  6700
# 7   12     GoAir    Chennai  Bangalore    Evening  non-stop  1.5  22  3900
# 8   13   AirAsia     Mumbai      Delhi      Night  non-stop  2.4  14  5000
# 9   14   Vistara  Bangalore    Chennai  Afternoon  non-stop  1.2  19  3600
# 10  15  SpiceJet      Delhi    Kolkata    Evening    1-stop  3.5   8  5800
# ...

# %%
pd.read_csv('student.tsv', sep='\t', usecols=['StudentID','CGPA','Package_LPA'])
# Out:
#     StudentID  CGPA  Package_LPA
# 0         101   8.1          6.5
# 1         102   7.5          5.2
# 2         103   9.0          9.1
# 3         104   6.8          4.0
# 4         105   8.7          8.3
# 5         106   7.9          6.0
# 6         107   9.3         10.5
# 7         108   6.5          3.8
# 8         109   8.4          7.2
# 9         110   7.2          5.0
# 10        111   8.9          8.9
# 11        112   6.9          4.5
# 12        113   9.5         11.2
# 13        114   7.8          6.3
# 14        115   8.2          7.5
# 15        116   7.4          5.6
# 16        117   8.6          8.1
# 17        118   6.7          4.2
# 18        119   9.1          9.8
# 19        120   7.3          5.4

# %%
pd.read_csv('flight.csv',usecols=['airline'])
# Out:
#      airline
# 0     Indigo
# 1   AirIndia
# 2   SpiceJet
# 3    Vistara
# 4     Indigo
# 5    AirAsia
# 6      GoAir
# 7    Vistara
# 8   SpiceJet
# 9     Indigo
# 10  AirIndia
# 11     GoAir
# 12   AirAsia
# 13   Vistara
# 14  SpiceJet
# 15    Indigo
# 16  AirIndia
# 17     GoAir
# 18   AirAsia
# 19   Vistara
# 20  SpiceJet
# 21    Indigo
# 22  AirIndia
# 23     GoAir
# 24   AirAsia
# 25   Vistara
# 26  SpiceJet
# 27    Indigo
# 28  AirIndia
# 29     GoAir

# %%
pd.read_csv('spotify.csv',skiprows=[1,2])
# Out:
#         Unnamed: 0.1  Unnamed: 0                track_id  \
# 0                  2           2  1iJBSr7s7jYXzM8EGcbK5b
# 1                  3           3  6lfxq3CG4xtTiEg7opyCyx
# 2                  4           4  5vjLSffimiIP26QG5WcN2K
# 3                  5           5  01MVOl9KtVTNfFiBU9I7dc
# 4                  6           6  6Vc5wAMmXdKIAM7WUoEb7N
# ...              ...         ...                     ...
# 113993        113995      113995  2C3TZjDRiAzdyViavDJ217
# 113994        113996      113996  1hIz5L4IB9hN3WRYPOCGPw
# 113995        113997      113997  6x8ZfSoqDjuNa5SVP5QjvX
# 113996        113998      113998  2e6sXL2bYv4bSz6VTdnfLs
# 113997        113999      113999  2hETkH7cOfqmz3LqZDHZf5
#
#                                      artists  \
# 0                     Ingrid Michaelson;ZAYN
# 1                               Kina Grannis
# 2                           Chord Overstreet
# 3                               Tyrone Wells
# 4       A Great Big World;Christina Aguilera
# ...

# %%
pd.read_csv('Player.csv', sep=':', on_bad_lines='skip')
# Out:
#     Player_Id,Player_Name,DOB,Batting_Hand,Bowling_Skill,Country,Is_Umpire,
# 0    1,SC Ganguly,8-Jul-72,Left_Hand,Right-arm medi...
# 1    2,BB McCullum,27-Sep-81,Right_Hand,Right-arm m...
# 2    3,RT Ponting,19-Dec-74,Right_Hand,Right-arm me...
# 3    4,DJ Hussey,15-Jul-77,Right_Hand,Right-arm off...
# 4    5,Mohammad Hafeez,17-Oct-80,Right_Hand,Right-a...
# ..                                                 ...
# 518            519,Subroto Das,NULL,NULL,NULL,India,1,
# 519           520,K Srinivasan,NULL,NULL,NULL,India,1,
# 520              521,VK Sharma,NULL,NULL,NULL,India,1,
# 521  523,AV Wankhade,14-Mar-92,Right_Hand,NULL,Indi...
# 522  524,B Aparajith,8-Jul-94,Right_Hand,Right-arm ...
#
# [523 rows x 1 columns]

# %%
pd.read_csv('spotify.csv',dtype={'mode':float})
# Out:
#         Unnamed: 0.1  Unnamed: 0                track_id  \
# 0                  0           0  5SuOikwiRyPMVoIQDJUgSV
# 1                  1           1  4qPNDBW1i3p13qLCt0Ki3A
# 2                  2           2  1iJBSr7s7jYXzM8EGcbK5b
# 3                  3           3  6lfxq3CG4xtTiEg7opyCyx
# 4                  4           4  5vjLSffimiIP26QG5WcN2K
# ...              ...         ...                     ...
# 113995        113995      113995  2C3TZjDRiAzdyViavDJ217
# 113996        113996      113996  1hIz5L4IB9hN3WRYPOCGPw
# 113997        113997      113997  6x8ZfSoqDjuNa5SVP5QjvX
# 113998        113998      113998  2e6sXL2bYv4bSz6VTdnfLs
# 113999        113999      113999  2hETkH7cOfqmz3LqZDHZf5
#
#                        artists  \
# 0                  Gen Hoshino
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113995           Rainy Lullaby
# ...

# %%
pd.read_csv('flight.csv')
# Out:
#     flight_id   airline source_city destination_city departure_time     stops  \
# 0           1    Indigo       Delhi           Mumbai        Morning  non-stop
# 1           2  AirIndia      Mumbai        Bangalore        Evening    1-stop
# 2           3  SpiceJet       Delhi          Chennai      Afternoon    1-stop
# 3           4   Vistara     Kolkata            Delhi        Morning  non-stop
# 4           5    Indigo   Bangalore           Mumbai          Night   2+-stop
# 5           6   AirAsia       Delhi          Kolkata      Afternoon  non-stop
# 6           7     GoAir      Mumbai          Chennai        Evening    1-stop
# 7           8   Vistara     Chennai            Delhi        Morning  non-stop
# 8           9  SpiceJet   Bangalore          Kolkata          Night    1-stop
# 9          10    Indigo       Delhi        Bangalore      Afternoon  non-stop
# 10         11  AirIndia     Kolkata           Mumbai        Morning    1-stop
# ...

# %%
def rename(name):
    if name == "AirIndia":
        return "AI"
    else:
        return name

# %%
rename("AirIndia")
# Out:
# 'AI'

# %%
pd.read_csv('flight.csv',converters={'airline':rename})
# Out:
#     flight_id   airline source_city destination_city departure_time     stops  \
# 0           1    Indigo       Delhi           Mumbai        Morning  non-stop
# 1           2        AI      Mumbai        Bangalore        Evening    1-stop
# 2           3  SpiceJet       Delhi          Chennai      Afternoon    1-stop
# 3           4   Vistara     Kolkata            Delhi        Morning  non-stop
# 4           5    Indigo   Bangalore           Mumbai          Night   2+-stop
# 5           6   AirAsia       Delhi          Kolkata      Afternoon  non-stop
# 6           7     GoAir      Mumbai          Chennai        Evening    1-stop
# 7           8   Vistara     Chennai            Delhi        Morning  non-stop
# 8           9  SpiceJet   Bangalore          Kolkata          Night    1-stop
# 9          10    Indigo       Delhi        Bangalore      Afternoon  non-stop
# 10         11        AI     Kolkata           Mumbai        Morning    1-stop
# ...

# %%
pd.read_csv('flight.csv',na_values=['Mumbai',])
# Out:
#     flight_id   airline source_city destination_city departure_time     stops  \
# 0           1    Indigo       Delhi              NaN        Morning  non-stop
# 1           2  AirIndia         NaN        Bangalore        Evening    1-stop
# 2           3  SpiceJet       Delhi          Chennai      Afternoon    1-stop
# 3           4   Vistara     Kolkata            Delhi        Morning  non-stop
# 4           5    Indigo   Bangalore              NaN          Night   2+-stop
# 5           6   AirAsia       Delhi          Kolkata      Afternoon  non-stop
# 6           7     GoAir         NaN          Chennai        Evening    1-stop
# 7           8   Vistara     Chennai            Delhi        Morning  non-stop
# 8           9  SpiceJet   Bangalore          Kolkata          Night    1-stop
# 9          10    Indigo       Delhi        Bangalore      Afternoon  non-stop
# 10         11  AirIndia     Kolkata              NaN        Morning    1-stop
# ...

# %%
dfs = pd.read_csv('flight.csv',chunksize=450)

# %%
for chunks in dfs:
    print(chunks.shape)
